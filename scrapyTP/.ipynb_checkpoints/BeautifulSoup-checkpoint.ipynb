# %% [markdown]
# # Import librairies

# %%
import requests
import csv
from bs4 import BeautifulSoup

# %% [markdown]
# # Elaborate the class

# %%
class Soup :
    def __init__(self,parser):
        self.parser = parser
    def importPage(self,page):
        page = requests.get(page)
        soup = BeautifulSoup(page.content, self.parser)
        return soup
    def importUrls(self,page):
        page = self.importPage(page)
        urls =  [child.find('a')['href'] for child in page.find_all('div',attrs={'class': 'item-img'})]
        return urls
    def getPrice(self,soup):
        try:
            price = soup.find('span',class_='amount').get_text()
        except AttributeError:
            price = '0'        
        return price
    def getFeatures(self,soup):
        result =  soup.find_all('h2',class_='ln22')
        features=[]
        for i in range(6):
            try:
                if(i==1):
                    result[i].find('strong').extract()
                    features.append(result[i].get_text()[1:])
                else:
                    features.append(result[i].find('a').get_text())
            except AttributeError:
                features.append('NaN')
        return features
    
    def getDescription(self,soup):
        result = [child.get_text() for child in soup.find('div',class_='span10').find_all('p')]
        return result
    
    def writeToCSV(self,soup,length):
        for j in range(length):
            result = soup.importUrls('https://www.avito.ma/fr/maroc/voitures-%C3%A0_vendre?o=1')
            with open('cars.csv', mode='w') as cars:
                cars = csv.writer(cars, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                cars.writerow(['modelOfYear', 'mileage', 'fuelType','brand','model','horsePower','price'])
            for i in range(35):
                url=result[i]
                page = soup.importPage(url)
            #--------------CSV--------------#
                features = self.getFeatures(page)
                features.append(self.getPrice(page))
                print(features)
                with open('cars.csv', mode='a') as cars:
                    writer = csv.writer(cars)
                    writer.writerow(features)
            #--------------CSV--------------#
        return t

# %%
soup = Soup('html.parser')
soup.writeToCSV(soup,3)
# Out:
# ['2015', '80 000 - 84 999', 'Diesel', 'Jeep', 'Cherokee', '8 CV', '230 000']
# ['2010', '50 000 - 54 999', 'Diesel', 'Dacia', 'Logan', '6 CV', '0']
# ['1999', '0 - 4 999', 'Diesel', 'Toyota', 'Auris', '8 CV', '48 000']
# ['1989', '15 000 - 19 999', 'Essence', 'Peugeot', '309', 'NaN', '22 000']
# ['2000', '120 000 - 129 999', 'Diesel', 'Opel', 'COMBO', '6 CV', '55 000']
# ['2006', '180 000 - 189 999', 'Essence', 'Toyota', 'Corolla', 'NaN', '0']
# ['2008', '140 000 - 149 999', 'Diesel', 'Volkswagen', 'GOLF 5', '8 CV', '0']
# ['2003', '300 000 - 349 999', 'Essence', 'Toyota', 'Corolla verso', '8 CV', '55 000']
# ['2006', '180 000 - 189 999', 'Essence', 'Toyota', 'Corolla', '7 CV', '0']
# ['2007', '150 000 - 159 999', 'Essence', 'Peugeot', '307', '8 CV', '0']
# ['1987', '95 000 - 99 999', 'Essence', 'Peugeot', '205', '5 CV', '18 000']
# ['NaN', '-', 'NaN', 'NaN', 'NaN', 'NaN', '0']
# ['2017', '10 000 - 14 999', 'Diesel', 'Maserati', 'other', '12 CV', '740 000']
# ['2014', '90 000 - 94 999', 'Diesel', 'Peugeot', '208', '6 CV', '98 000']
# ['2015', '100 000 - 109 999', 'Diesel', 'Citroen', 'Berlingo', 'NaN', '125 000']
# ['1994', '30 000 - 34 999', 'Diesel', 'Mercedes-Benz', 'Classe E', '5 CV', '0']
# ['1986', '0 - 4 999', 'Diesel', 'Volkswagen', 'GOLF 2', '6 CV', '32 000']
# ['1999', '120 000 - 129 999', 'Diesel', 'BMW', 'M5', 'NaN', '25 000']
# ['2017', '15 000 - 19 999', 'Electrique', 'Alfa Romeo', '75', '7 CV', '0']
# ['2014', '95 000 - 99 999', 'Diesel', 'Mercedes-Benz', 'Classe C', 'NaN', '0']
# ['2001', '250 000 - 299 999', 'Diesel', 'Volkswagen', 'GOLF 4', '8 CV', '80 000']
# ['2002', '30 000 - 34 999', 'Essence', 'Fiat', 'Palio', '6 CV', '37 000']
# ['1985', '400 000 - 449 999', 'Essence', 'Renault', '12', '6 CV', '8 500']
# ['2014', '90 000 - 94 999', 'Essence', 'Volkswagen', 'GOLF 7', 'NaN', '260 000']
# ['1988', '120 000 - 129 999', 'Essence', 'Fiat', 'Uno', '6 CV', '20 000']
# ['2003', '190 000 - 199 999', 'Diesel', 'Mitsubishi', 'canter', 'NaN', '165 000']
# ['2018', '5 000 - 9 999', 'Diesel', 'Fiat', '500', 'NaN', '250 000']
# ['2009', '90 000 - 94 999', 'Essence', 'Chevrolet', 'Epica', 'NaN', '28 000']
# ['2009', '150 000 - 159 999', 'Diesel', 'Renault', 'Megane', 'NaN', '82 000']
# ['2000', '180 000 - 189 999', 'Diesel', 'Peugeot', '406', '8 CV', '45 000']
# ['1998', '250 000 - 299 999', 'Essence', 'Mercedes-Benz', 'Classe CLK', '11 CV', '38 000']
# ['1998', '0 - 4 999', 'Diesel', 'Fiat', 'Punto', 'NaN', '47 000']
# ['2010', '130 000 - 139 999', 'Essence', 'Renault', 'Laguna', 'NaN', '0']
# ['2000', '250 000 - 299 999', 'Diesel', 'Volkswagen', 'GOLF 4', 'NaN', '80 000']
# ['2017', '45 000 - 49 999', 'Diesel', 'Kia', 'Sorento', '9 CV', '265 000']
# ['2015', '80 000 - 84 999', 'Diesel', 'Jeep', 'Cherokee', '8 CV', '230 000']
# ['2010', '50 000 - 54 999', 'Diesel', 'Dacia', 'Logan', '6 CV', '0']
# ['1999', '0 - 4 999', 'Diesel', 'Toyota', 'Auris', '8 CV', '48 000']
# ['1989', '15 000 - 19 999', 'Essence', 'Peugeot', '309', 'NaN', '22 000']
# ['2000', '120 000 - 129 999', 'Diesel', 'Opel', 'COMBO', '6 CV', '55 000']
# ['2006', '180 000 - 189 999', 'Essence', 'Toyota', 'Corolla', 'NaN', '0']
# ['2008', '140 000 - 149 999', 'Diesel', 'Volkswagen', 'GOLF 5', '8 CV', '0']
# ['2003', '300 000 - 349 999', 'Essence', 'Toyota', 'Corolla verso', '8 CV', '55 000']
# ['2006', '180 000 - 189 999', 'Essence', 'Toyota', 'Corolla', '7 CV', '0']
# ['2007', '150 000 - 159 999', 'Essence', 'Peugeot', '307', '8 CV', '0']
# ['1987', '95 000 - 99 999', 'Essence', 'Peugeot', '205', '5 CV', '18 000']
# ['NaN', '-', 'NaN', 'NaN', 'NaN', 'NaN', '0']
# ['2017', '10 000 - 14 999', 'Diesel', 'Maserati', 'other', '12 CV', '740 000']
# ['2014', '90 000 - 94 999', 'Diesel', 'Peugeot', '208', '6 CV', '98 000']
# ['2015', '100 000 - 109 999', 'Diesel', 'Citroen', 'Berlingo', 'NaN', '125 000']
# ['1994', '30 000 - 34 999', 'Diesel', 'Mercedes-Benz', 'Classe E', '5 CV', '0']
# ['1986', '0 - 4 999', 'Diesel', 'Volkswagen', 'GOLF 2', '6 CV', '32 000']
# ['1999', '120 000 - 129 999', 'Diesel', 'BMW', 'M5', 'NaN', '25 000']
# ['2017', '15 000 - 19 999', 'Electrique', 'Alfa Romeo', '75', '7 CV', '0']
# ['2014', '95 000 - 99 999', 'Diesel', 'Mercedes-Benz', 'Classe C', 'NaN', '0']
# ['2001', '250 000 - 299 999', 'Diesel', 'Volkswagen', 'GOLF 4', '8 CV', '80 000']
# ['2002', '30 000 - 34 999', 'Essence', 'Fiat', 'Palio', '6 CV', '37 000']
# ['1985', '400 000 - 449 999', 'Essence', 'Renault', '12', '6 CV', '8 500']
# ['2014', '90 000 - 94 999', 'Essence', 'Volkswagen', 'GOLF 7', 'NaN', '260 000']
# ['1988', '120 000 - 129 999', 'Essence', 'Fiat', 'Uno', '6 CV', '20 000']
# ['2003', '190 000 - 199 999', 'Diesel', 'Mitsubishi', 'canter', 'NaN', '165 000']
# ['2018', '5 000 - 9 999', 'Diesel', 'Fiat', '500', 'NaN', '250 000']
# ['2009', '90 000 - 94 999', 'Essence', 'Chevrolet', 'Epica', 'NaN', '28 000']
# ['2009', '150 000 - 159 999', 'Diesel', 'Renault', 'Megane', 'NaN', '82 000']
# ['2000', '180 000 - 189 999', 'Diesel', 'Peugeot', '406', '8 CV', '45 000']
# ['1998', '250 000 - 299 999', 'Essence', 'Mercedes-Benz', 'Classe CLK', '11 CV', '38 000']
# ['1998', '0 - 4 999', 'Diesel', 'Fiat', 'Punto', 'NaN', '47 000']
# ['2010', '130 000 - 139 999', 'Essence', 'Renault', 'Laguna', 'NaN', '0']
# ['2000', '250 000 - 299 999', 'Diesel', 'Volkswagen', 'GOLF 4', 'NaN', '80 000']
# ['2017', '45 000 - 49 999', 'Diesel', 'Kia', 'Sorento', '9 CV', '265 000']
# ['2015', '80 000 - 84 999', 'Diesel', 'Jeep', 'Cherokee', '8 CV', '230 000']
# ['2010', '50 000 - 54 999', 'Diesel', 'Dacia', 'Logan', '6 CV', '0']
# ['1999', '0 - 4 999', 'Diesel', 'Toyota', 'Auris', '8 CV', '48 000']
# ['1989', '15 000 - 19 999', 'Essence', 'Peugeot', '309', 'NaN', '22 000']
# ['2000', '120 000 - 129 999', 'Diesel', 'Opel', 'COMBO', '6 CV', '55 000']
# ['2006', '180 000 - 189 999', 'Essence', 'Toyota', 'Corolla', 'NaN', '0']
# ['2008', '140 000 - 149 999', 'Diesel', 'Volkswagen', 'GOLF 5', '8 CV', '0']
# ['2003', '300 000 - 349 999', 'Essence', 'Toyota', 'Corolla verso', '8 CV', '55 000']
# ['2006', '180 000 - 189 999', 'Essence', 'Toyota', 'Corolla', '7 CV', '0']
# ['2007', '150 000 - 159 999', 'Essence', 'Peugeot', '307', '8 CV', '0']
# ['1987', '95 000 - 99 999', 'Essence', 'Peugeot', '205', '5 CV', '18 000']
# ['NaN', '-', 'NaN', 'NaN', 'NaN', 'NaN', '0']
# ['2017', '10 000 - 14 999', 'Diesel', 'Maserati', 'other', '12 CV', '740 000']
# ['2014', '90 000 - 94 999', 'Diesel', 'Peugeot', '208', '6 CV', '98 000']
# ['2015', '100 000 - 109 999', 'Diesel', 'Citroen', 'Berlingo', 'NaN', '125 000']
# ['1994', '30 000 - 34 999', 'Diesel', 'Mercedes-Benz', 'Classe E', '5 CV', '0']
# ['1986', '0 - 4 999', 'Diesel', 'Volkswagen', 'GOLF 2', '6 CV', '32 000']
# ['1999', '120 000 - 129 999', 'Diesel', 'BMW', 'M5', 'NaN', '25 000']
# ['2017', '15 000 - 19 999', 'Electrique', 'Alfa Romeo', '75', '7 CV', '0']
# ['2014', '95 000 - 99 999', 'Diesel', 'Mercedes-Benz', 'Classe C', 'NaN', '0']
# ['2001', '250 000 - 299 999', 'Diesel', 'Volkswagen', 'GOLF 4', '8 CV', '80 000']
# ['2002', '30 000 - 34 999', 'Essence', 'Fiat', 'Palio', '6 CV', '37 000']
# ['1985', '400 000 - 449 999', 'Essence', 'Renault', '12', '6 CV', '8 500']
# ['2014', '90 000 - 94 999', 'Essence', 'Volkswagen', 'GOLF 7', 'NaN', '260 000']
# ['1988', '120 000 - 129 999', 'Essence', 'Fiat', 'Uno', '6 CV', '20 000']
# ['2003', '190 000 - 199 999', 'Diesel', 'Mitsubishi', 'canter', 'NaN', '165 000']
# ['2018', '5 000 - 9 999', 'Diesel', 'Fiat', '500', 'NaN', '250 000']
# ['2009', '90 000 - 94 999', 'Essence', 'Chevrolet', 'Epica', 'NaN', '28 000']
# ['2009', '150 000 - 159 999', 'Diesel', 'Renault', 'Megane', 'NaN', '82 000']
# ['2000', '180 000 - 189 999', 'Diesel', 'Peugeot', '406', '8 CV', '45 000']
# ['1998', '250 000 - 299 999', 'Essence', 'Mercedes-Benz', 'Classe CLK', '11 CV', '38 000']
# ['1998', '0 - 4 999', 'Diesel', 'Fiat', 'Punto', 'NaN', '47 000']
# ['2010', '130 000 - 139 999', 'Essence', 'Renault', 'Laguna', 'NaN', '0']
# ['2000', '250 000 - 299 999', 'Diesel', 'Volkswagen', 'GOLF 4', 'NaN', '80 000']
# ['2017', '45 000 - 49 999', 'Diesel', 'Kia', 'Sorento', '9 CV', '265 000']
# [<strong>Année-Modèle:</strong>,
#  <strong>Kilométrage:</strong>,
#  <strong>Type de carburant:</strong>,
#  <strong>Marque:</strong>,
#  <strong>Modèle:</strong>,
#  <strong>Puissance fiscale:</strong>]
